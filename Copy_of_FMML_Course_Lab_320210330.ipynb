# %% [markdown]
# <a href="https://colab.research.google.com/github/manusri-kim/fmmllabs-and-projects-/blob/main/Copy_of_FMML_Course_Lab_320210330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-09 11:40:39--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   139MB/s    in 0.5s
#
# 2022-06-09 11:40:42 (139 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-9-22b61ab6595e> in <module>()
#       2 X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
#       3 X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
# ----> 4 predictions = gnb.predict(X_scan)
#       5 color_map = ['r', 'g', 'b']
#       6 plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py in predict(self, X)
#      79             Predicted target values for X.
#      80         """
# ---> 81         check_is_fitted(self)
#      82         X = self._check_X(X)
#      83         jll = self._joint_log_likelihood(X)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This GaussianNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3483   1708.07747v2  We present Fashion-MNIST, a new dataset compri...    cs
# 12552  1802.09578v1  Local polynomial regression (Fan & Gijbels, 19...  stat
# 17916  cs/9603101v1  We introduce an algorithm for combinatorial se...    cs
# 30148  1711.07888v1  The objective of this paper is 3D shape unders...    cs
# 7189   1710.11469v3  When training a deep network for image classif...  stat
# ...             ...                                                ...   ...
# 15965  1607.05408v1  Identifying the language of social media messa...    cs
# 7179   1710.10866v1  Approximate dynamic programming algorithms, su...  stat
# 9973   1512.00573v1  To accomplish tasks in human-centric indoor en...    cs
# 15945  1607.00359v1  Hidden Markov Model (HMM) is often regarded as...    cs
# 5420    1210.1258v1  Discovering the latent structure from many obs...    cs
#
#                                                    title  year  \
# 3483   Fashion-MNIST: a Novel Image Dataset for Bench...  2017
# 12552  Near-Linear Time Local Polynomial Nonparametri...  2018
# 17916  Quantum Computing and Phase Transitions in Com...  1996
# 30148  SilNet : Single- and Multi-View Reconstruction...  2017
# 7189   Conditional Variance Penalties and Domain Shif...  2017
# ...                                                  ...   ...
# 15965  Discriminating between similar languages in Tw...  2016
# 7179   Unifying Value Iteration, Advantage Learning, ...  2017
# 9973   Object-based World Modeling in Semi-Static Env...  2015
# 15945  Moving Toward High Precision Dynamical Modelli...  2016
# 5420   Unfolding Latent Tree Structures using 4th Ord...  2012
#
#                                                 keywords
# 3483   [comprising, grayscale, categories, replacemen...
# 12552  [polynomial, regression, important, nonparamet...
# 17916  [introduce, algorithm, combinatorial, computer...
# 30148  [objective, understanding, introduce, architec...
# 7189   [classification, distinguish, classification, ...
# ...                                                  ...
# 15965  [identifying, important, linguistic, processin...
# 7179   [approximate, programming, algorithms, approxi...
# 9973   [accomplish, environments, represent, understa...
# 15945  [dynamical, applications, recognition, underly...
# 5420   [discovering, structure, variables, important,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3483     [comprising, grayscale, categories, replacemen...
# 12552    [polynomial, regression, important, nonparamet...
# 17916    [introduce, algorithm, combinatorial, computer...
# 30148    [objective, understanding, introduce, architec...
# 7189     [classification, distinguish, classification, ...
#                                ...
# 2919     [introduced, successfully, recognition, scenar...
# 5390     [correlated, supervised, algorithm, regression...
# 15670    [introduce, computationally, efficient, simult...
# 2279     [probability, distributions, beneficial, appli...
# 16189    [institute, technology, university, submission...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8732 words.
# Out of those 4575 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="56531af8-2ecf-4494-b30a-586be57418b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56531af8-2ecf-4494-b30a-586be57418b4")) {                    Plotly.newPlot(                        "56531af8-2ecf-4494-b30a-586be57418b4",                        [{"x":["algorithms","structure","replacement","comprising","categories","available","grayscale","benchmarking","complexities","polynomial","regression","dimensional","effectiveness","simulation","quadratic","efficiency","estimation","nonparametric","straightforward","estimates","complexity","computation","accelerate","applicability","implementation","important","applications","significantly","algorithm","difficult","exploiting","transition","concentrated","introduce","computing","classical","combinatorial","instances","specifically","amplitude","previously","furthermore","empirical","evaluation","unproductive","computers","solutions","transitions","parallelism","understanding","objective","realistic","prediction","demonstrate","architecture","performance","challenging","generalisation","benchmark","reconstruction","silhouettes","silhouette","convolutional","distinguish","penalties","substantially","equivalent","influence","generally","adversarial","variables","classification","interventions","sometimes","distribution","orthogonal","partially","typically","condition","brightness","robustness","identifier","minimizing","conditional","consistency","following","validation","implement","detection","lightweight","recognition","effectively","extensively","significant","importance","particular","improvements","constrained","divergence","exponential","recommender","relationship","approximation","multiplicative","variations","satisfying","analytics","experiments","convergence","euclidean","proportion","symmetric","achieving","constraints","reasonable","practically","approximations","factorisation","advantages","clustering","distances","synthetic","respectively","dirichlet","obtaining","technique","providing","decomposition","efficient","unsupervised","allocation","unlabeled","meaningful","parameters","exploring","overlapping","container","locations","temporally","associating","spatially","candidate","aggregating","detecting","improving","detections","suppression","aggregated","concerning","positives","preprocessing","inference","submodular","interpreting","negatives","accelerated","incorrect","approaches","elimination","discriminative","guarantees","techniques","conducted","functions","processing","expansion","shortcoming","guaranteed","phenomena","overfitted","phenomenon","parametrized","presented","interpolated","properties","classifiers","polynomially","experimentally","understood","analytically","exponentially","tractable","theoretical","similarly","establish","generalization","laplacian","understand","overfitting","manifested","optimization","experimental","increases","observation","selection","operating","estimating","predictive","alternatives","determine"],"y":[633,340,4,14,77,310,10,10,18,48,122,185,211,81,36,165,202,20,18,73,258,138,21,47,142,342,425,284,820,140,91,35,8,325,134,99,38,110,165,5,102,164,143,259,2,13,144,14,15,167,170,53,219,555,254,874,262,5,181,108,5,3,381,28,4,37,64,47,78,106,121,515,5,30,227,15,52,112,38,2,97,2,58,85,57,88,40,77,319,13,346,123,28,251,84,269,109,69,31,43,23,94,116,14,77,11,12,624,112,32,12,14,88,148,40,13,32,1,78,136,27,143,73,19,43,243,83,67,407,122,26,48,54,242,35,26,4,37,21,4,17,41,17,83,107,14,8,13,17,11,34,179,15,8,5,18,8,397,12,92,60,381,74,236,305,20,3,40,34,1,17,8,192,4,207,112,6,57,15,13,18,25,165,16,51,121,19,69,19,2,343,366,51,49,157,18,74,58,23,66],"type":"bar"},{"x":["algorithms","structure","replacement","comprising","categories","available","gr ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4575,), (4575, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Spatial</span> <span style=''>and</span> <span style=''>Temporal</span> <span style=''>Non</span> <span style=''>Local</span> <span style=''>Filter</span> <span style=''>Based</span> <span style=''>Data</span> <span style=''>Fusion</span> <br/><br/><span style=''>The</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>in</span> <span style=''>remote</span> <span style=''>sensing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instruments</span> <span style=''>that</span> <span style=''>balances</span> <span style=''>the</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>resolution</span> <span style=''>and</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3608247422680413);'>frequency</span> <span style=''>limits</span> <span style=''>our</span> <span style=''>capacity</span> <span style=''>to</span> <span style=''>monitor</span> <span style=''>spatial</span> <span style=''>and</span> <span style=''>temporal</span> <span style=''>dynamics</span> <span style='background-color:rgba(0, 255, 0, 0.3977272727272727);'>effectively</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>spatiotemporal</span> <span style=''>data</span> <span style=''>fusion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>as</span> <span style=''>a</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3467048710601719);'>effective</span> <span style=''>way</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>remote</span> <span style=''>sensing</span> <span style=''>data</span> <span style=''>with</span> <span style=''>both</span> <span style=''>high</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>resolution</span> <span style=''>and</span> <span style=''>high</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3608247422680413);'>frequency</span> <span style=''>by</span> <span style=''>blending</span> <span style='background-color:rgba(255, 0, 0, 0.3360995850622407);'>observations</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>sensors</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.35795954265611263);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3384615384615384);'>characteristics</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>and</span> <span style=''>temporal</span> <span style=''>non</span> <span style=''>local</span> <span style=''>filter</span> <span style=''>based</span> <span style=''>fusion</span> <span style=''>model</span> <span style=''>(STNLFFM)</span> <span style=''>to</span> <span style=''>enhance</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>capacity</span> <span style=''>and</span> <span style=''>accuracy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>for</span> <span style=''>complex</span> <span style=''>changed</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>landscapes</span> <span style=''>The</span> <span style=''>STNLFFM</span> <span style=''>method</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>ANOVA</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>RKHS</span> <span style=''>of</span> <span style=''>zero</span> <span style=''>mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>for</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>analysis</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>H</span> <span style=''>of</span> <span style=''>real</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>a</span> <span style=''>suitable</span> <span style=''>measure</span> <span style=''>mu</span> <span style=''>over</span> <span style=''>the</span> <span style=''>source</span> <span style=''>space</span> <span style=''>D</span> <span style=''>(subset</span> <span style=''>of</span> <span style=''>R)</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompose</span> <span style=''>H</span> <span style=''>as</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>a</span> <span style=''>subspace</span> <span style=''>of</span> <span style=''>centered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>for</span> <span style=''>mu</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style=''>in</span> <span style=''>H</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>ANOVA</span> <span style=''>kernels</span> <span style=''>for</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>ANOVA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>elegantly</span> <span style=''>derived</span> <span style=''>either</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>kernels</span> <span style=''>appear</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convenient</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style=''>e</span> <span style=''>ffect</span> <span style=''>of</span> <span style=''>each</span> <span style=''>(group</span> <span style=''>of)</span> <span style=''>variable(s)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>indices</span> <span style=''>without</span> <span style=''>recursivity</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Scalable</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>Multiclass</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>MUCCA</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>multiclass</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>in</span> <span style=''>weighted</span> <span style=''>graphs</span> <span style=''>Unlike</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style=''>proposed</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>the</span> <span style=''>same</span> <span style=''>task</span> <span style=''>MUCCA</span> <span style=''>works</span> <span style=''>in</span> <span style=''>time</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>game</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>test</span> <span style=''>labels</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>Nash</span> <span style='background-color:rgba(0, 255, 0, 0.3913043478260869);'>Equilibrium</span> <span style=''>of</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>game</span> <span style=''>However</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>achieve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scalability</span> <span style=''>we</span> <span style=''>find</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3913043478260869);'>equilibrium</span> <span style=''>on</span> <span style=''>a</span> <span style=''>spanning</span> <span style=''>tree</span> <span style=''>of</span> <span style=''>the</span> <span style=''>original</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>real</span> <span style=''>world</span> <span style=''>data</span> <span style=''>reveal</span> <span style=''>that</span> <span style=''>MUCCA</span> <span style=''>is</span> <span style=''>much</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.368421052631579);'>competitors</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.35384615384615375);'>achieving</span> <span style=''>a</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.4821428571428573);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Threshold</span> <span style=''>Sampling</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>Sampling</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>both</span> <span style=''>computer</span> <span style=''>science</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style=''>issues</span> <span style=''>arise</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style=''>a</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>sampling</span> <span style=''>These</span> <span style=''>include</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerations</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style=''>a</span> <span style=''>good</span> <span style=''>sampling</span> <span style=''>design</span> <span style=''>and</span> <span style=''>ensuring</span> <span style=''>there</span> <span style=''>are</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantities</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerations</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style=''>data</span> <span style=''>and</span> <span style=''>ensuring</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>fits</span> <span style=''>within</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>existing</span> <span style=''>sampling</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>only</span> <span style=''>able</span> <span style=''>to</span> <span style=''>address</span> <span style=''>all</span> <span style=''>of</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>in</span> <span style=''>limited</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>address</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>in</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1292372881355932)
# 	knowledge (0.1172316384180791)
# 	information (0.24258474576271186)
# 	segmentation (0.06991525423728813)
# 	processing (0.10769774011299435)
# 	architecture (0.08968926553672317)
# 	detection (0.1126412429378531)
# 	recognition (0.12217514124293785)
# 	different (0.2725988700564972)
# 	convolutional (0.13453389830508475)
#
# Some Statistics words are:
# 	theoretical (0.15294715447154472)
# 	stochastic (0.14532520325203252)
# 	algorithm (0.38973577235772355)
# 	variables (0.14634146341463414)
# 	distribution (0.1875)
# 	estimation (0.18140243902439024)
# 	statistical (0.1676829268292683)
# 	dimensional (0.1915650406504065)
# 	inference (0.20477642276422764)
# 	regression (0.1875)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ea45c0ab-b85d-4cfd-96b0-3a9180295545" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea45c0ab-b85d-4cfd-96b0-3a9180295545")) {                    Plotly.newPlot(                        "ea45c0ab-b85d-4cfd-96b0-3a9180295545",                        [{"x":["algorithms","structure","replacement","comprising","categories","available","grayscale","benchmarking","complexities","polynomial","regression","dimensional","effectiveness","simulation","quadratic","efficiency","estimation","nonparametric","straightforward","estimates","complexity","computation","accelerate","applicability","implementation","important","applications","significantly","algorithm","difficult","exploiting","transition","concentrated","introduce","computing","classical","combinatorial","instances","specifically","amplitude","previously","furthermore","empirical","evaluation","unproductive","computers","solutions","transitions","parallelism","understanding","objective","realistic","prediction","demonstrate","architecture","performance","challenging","generalisation","benchmark","reconstruction","silhouettes","silhouette","convolutional","distinguish","penalties","substantially","equivalent","influence","generally","adversarial","variables","classification","interventions","sometimes","distribution","orthogonal","partially","typically","condition","brightness","robustness","identifier","minimizing","conditional","consistency","following","validation","implement","detection","lightweight","recognition","effectively","extensively","significant","importance","particular","improvements","constrained","divergence","exponential","recommender","relationship","approximation","multiplicative","variations","satisfying","analytics","experiments","convergence","euclidean","proportion","symmetric","achieving","constraints","reasonable","practically","approximations","factorisation","advantages","clustering","distances","synthetic","respectively","dirichlet","obtaining","technique","providing","decomposition","efficient","unsupervised","allocation","unlabeled","meaningful","parameters","exploring","overlapping","container","locations","temporally","associating","spatially","candidate","aggregating","detecting","improving","detections","suppression","aggregated","concerning","positives","preprocessing","inference","submodular","interpreting","negatives","accelerated","incorrect","approaches","elimination","discriminative","guarantees","techniques","conducted","functions","processing","expansion","shortcoming","guaranteed","phenomena","overfitted","phenomenon","parametrized","presented","interpolated","properties","classifiers","polynomially","experimentally","understood","analytically","exponentially","tractable","theoretical","similarly","establish","generalization","laplacian","understand","overfitting","manifested","optimization","experimental","increases","observation","selection","operating","estimating","predictive","alternatives","determine","bootstrap","bootstrapping","resampling","considering","fortunately","aggregation","parameter","variability","characteristics","recurrent","trainable","acceptable","attention","alternative","sequential","synthesis","component","efficiently","synthesized","experiment","parallelizability","describes","alleviate","sufficiently","belonging","generated","framework","eventually","unambiguous","information","knowledge","languages","speculate","extraction","paraphrase","automatically","represents","representation","considered","extracted","documents","representations","abstractions","challenges","dimensionality","visualization","analyzing","interpret","transferring","functionality","different","visualizing","application","accelerators","synergistic"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	generalisations
# 	reinterpret
# 	distinguishability
# 	geostatistical
# 	undersampled
# 	intracellular
# 	cytometry
# 	uncollapsed
# 	operationalize
# 	quantiles
# 	popularly
# 	histories
# 	regressionclassification
# 	inexactly
# 	marginalize
# 	bernsteins
# 	modulating
# 	parameterizes
# 	itinerary
# 	roadworks
# Some words which never appear in Statistics papers:
# 	grayscale
# 	unproductive
# 	container
# 	associating
# 	suppression
# 	parallelizability
# 	unambiguous
# 	speculate
# 	paraphrase
# 	accelerators
# 	accelerator
# 	omissions
# 	subprograms
# 	solomonoffs
# 	asymmetrical
# 	disjunction
# 	satisfiability
# 	conjunctions
# 	connectives
# 	thereafter

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0399756801945586e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7441666666666666
